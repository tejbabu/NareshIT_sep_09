# %%
Radius=eval(input("enter raidus of circle"))
Area=3.14*Radius*Radius
print(f"The radius of a circle = {Area}")
# Out:
# enter raidus of circle 5
# The radius of a circle = 78.5

# %%
# WAP ask the user area of rectangle
length=eval(input("enter length of a triange"))
breadth=eval(input("enter breadth of triange"))
Area_of_rectangle=length*breadth
print(f"The area of rectangle: {Area_of_rectangle}")
# Out:
# enter length of a triange 34
# enter breadth of triange 32
# The area of rectangle: 1088

# %%
# WAP ask the user area of square
Area=eval(input("enter "))
